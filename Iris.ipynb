# %% [markdown]
# <a href="https://colab.research.google.com/github/jkabila/Iris/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import plotly.express as px

# %%
import vega_datasets

# %% [markdown]
# # **Data preprocessing**

# %%
df=vega_datasets.data.iris()
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
# supervised
#depandent-species
#continious-sepallength,sepalwidth,petalength,petalwidth
#cata-species

# %%
# correlation test to identify the relation

# %%
df.corr()
# Out:
# <ipython-input-6-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              sepalLength  sepalWidth  petalLength  petalWidth
# sepalLength     1.000000   -0.117570     0.871754    0.817941
# sepalWidth     -0.117570    1.000000    -0.428440   -0.366126
# petalLength     0.871754   -0.428440     1.000000    0.962865
# petalWidth      0.817941   -0.366126     0.962865    1.000000

# %%
#sepallength and width (0)
#sepallength and petallength (1) directly proportional
#sepal length and petalwidth (1)
#sepalwidth and length (0)
#sepalwidth and petallength(-1)indirectly proportional
#sepalwidth and petalwidth(-1)
#petallength and sepallength(1)
#petallength and sepalwidth(-1)
#petallength and petalwidth(1)
#petalwidth and sepallength(1)
#petalwidth and sepalwidth(-1)
#petalwidth and petallength(1)

# %%
#sepallenghth and sepalwidth h0 rejected
#petallenth and petalwidth h0 rejected
#sepalength and petallength h0 rejected
#sepallength and petalwidth h0 rejaected
#sepalwidth and petallength
#sepalwidth and petalwidth
#petallength and sepallenth
#petallength and sepalwidth
#petalwidth and sepallength
#petalwidth and sepalwidth

# %%
#sepallength,sepalwidth

for i in range(20):
  sample1=df.sepalLength.sample(frac=0.04)
  sample2=df.sepalWidth.sample(frac=0.04)
  t_test,p_value=stats.ttest_ind(sample1,sample2)

  if p_value> 0.5:
    print("H0 is accepted")
  else:
    print("H0 is rejected")
# Out:
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected

# %%
#petallenght,petallwidth

for i in range(20):
  sample1=df.petalLength.sample(frac=0.04)
  sample2=df.petalWidth.sample(frac=0.04)
  t_test,p_value=stats.ttest_ind(sample1,sample2)

  if p_value> 0.5:
    print("H0 is accepted")
  else:
    print("H0 is rejected")
# Out:
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected

# %%
#sepalength and petallength

for i in range(20):
  sample1=df.sepalLength.sample(frac=0.04)
  sample2=df.petalLength.sample(frac=0.04)
  t_test,p_value=stats.ttest_ind(sample1,sample2)

  if p_value> 0.5:
    print("H0 is accepted")
  else:
    print("H0 is rejected")
# Out:
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected

# %%
#sepallength and petalwidth
for i in range(20):
  sample1=df.sepalLength.sample(frac=0.04)
  sample2=df.petalWidth.sample(frac=0.04)
  t_test,p_value=stats.ttest_ind(sample1,sample2)

  if p_value> 0.5:
    print("H0 is accepted")
  else:
    print("H0 is rejected")
# Out:
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected

# %%
#sepalwidth and petallength
for i in range(20):
  sample1=df.sepalWidth.sample(frac=0.04)
  sample2=df.petalLength.sample(frac=0.04)
  t_test,p_value=stats.ttest_ind(sample1,sample2)

  if p_value> 0.5:
    print("H0 is accepted")
  else:
    print("H0 is rejected")
# Out:
# H0 is accepted
# H0 is accepted
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is accepted
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is rejected
# H0 is accepted
# H0 is rejected
# H0 is rejected
# H0 is accepted

# %% [markdown]
# # **Data visualization**

# %%
fig=px.bar(df,x="sepalLength",y="sepalWidth",hover_name="petalLength",color="species",
color_discrete_sequence=["#420080", "#6900cc","#9c33ff"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
